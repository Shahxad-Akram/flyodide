# %%
import pandas as pd

# Example DataFrame
df = pd.DataFrame({
    'col1': [1, 2],
    'col2': [0.5, 0.75]
})

# Convert to dictionary
dictionary = df.to_json()

dictionary
# Out:
# '{"col1":{"0":1,"1":2},"col2":{"0":0.5,"1":0.75}}'
